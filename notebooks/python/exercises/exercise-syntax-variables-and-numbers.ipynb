# %%
# 演習のセットアップ（変更しないでください）
# !pip install --upgrade --no-cache-dir git+https://github.com/yusukem99/pythoncorse1.git

# %% [markdown]
# **このノートブックは [Python](https://www.kaggle.com/learn/python) コースの演習です。チュートリアルは [こちらのリンク](https://www.kaggle.com/colinmorris/hello-python) から参照できます。**
#
# ---

# %% [markdown]
# Pythonのコーディング問題に初めて挑戦します。Kaggle Notebookを使うのが初めての方も、ようこそ！
#
# ノートブックはテキストとコードのブロック（「セル」と呼ばれます）で構成されています。それぞれ編集可能ですが、主にコードセルを編集して問題に答えていきます。
#
# まず、下のコードセルを実行してみてください（►ボタンを押すか、セルをクリックしてCtrl+Enterを押します）。

# %%
print("Pythonコードの実行に成功しました")
print("おめでとうございます！")

# %% [markdown]
# 上のセルにもう1行コードを追加して、再実行してみてください。
#
# 次に、もう少し進んだ操作をしてみましょう：既存のコードセルをクリックし、Escキーを押してから、`a`キーまたは`b`キーを押すと新しいコードセルを追加できます。`a`キーは現在のセルの上に、`b`キーは下にセルを追加します。
#
# これでNotebookの使い方がわかりましたね。
#
# 各実践演習は、フィードバックとコードチェックの仕組みをセットアップすることから始まります。下のコードセルを実行してセットアップしてください。その後、問題0に進む準備が整います。

# %%
# 演習のセットアップ（変更しないでください）
from learntools.core import binder; binder.bind(globals())
from learntools.python.ex1 import *
print('セットアップ完了。')

# %% [markdown]
# *これは、すべてのKaggleコースの実践演習で使用する形式を紹介するための簡単な問題です。*
#
# **あなたの好きな色は何ですか？**
#
# この問題を完了するには、下のセルに適切な値を持つ `color` という変数を作成してください。すでにセルに用意されている `q0.check()` という関数呼び出しが、あなたの解答をチェックします。

# %%
# 下の行に適切な値を持つcolorという変数を作成してください
# （Pythonの文字列は 'シングル' または "ダブル" クォートで囲む必要があります）
____

# 解答を確認する
q0.check()

# %% [markdown]
# 正解できませんでしたか？自分の好きな色がわからないなんてことはないですよね？！
#
# 下の行の `#` を削除して、いずれかの行を実行してください。`#` を削除する行を選ぶことで、ヒントを見るか完全な解答を見るかを選べます。
#
# `#` を削除することを「コメントを外す（アンコメント）」と呼びます。Pythonが実行しない「コメント」から、Pythonが実行するコードに変わるからです。

# %%
# ヒントを表示するにはコメントを外してください
#q0.hint()
# 解答を表示するにはコメントを外してください
#q0.solution()

# %% [markdown]
# 以降の問題も同じ形式です。変わるのは問題番号だけです。次の問題では `q1.check()`、`q1.hint()`、`q1.solution()` を呼び出し、問題2では `q2.check()` を呼び出す、という具合です。

# %% [markdown]
# <hr/>
#
# # 1.
#
# 下のコードを完成させてください。参考として、利用可能な算術演算子の表を示します：
#
#
#
# | 演算子     | 名前           | 説明                                            |
# |--------------|----------------|--------------------------------------------------------|
# | ``a + b``    | 加算       | ``a`` と ``b`` の和                                 |
# | ``a - b``    | 減算    | ``a`` と ``b`` の差                          |
# | ``a * b``    | 乗算 | ``a`` と ``b`` の積                             |
# | ``a / b``    | 除算  | ``a`` を ``b`` で割った商                            |
# | ``a // b``   | 切り捨て除算 | ``a`` を ``b`` で割った商（小数部分を切り捨て） |
# | ``a % b``    | 剰余        | ``a`` を ``b`` で割った余り     |
# | ``a ** b``   | べき乗 | ``a`` の ``b`` 乗                     |
# | ``-a``       | 符号反転       | ``a`` の負の値                                  |
#
# <span style="display:none"></span>

# %%
pi = 3.14159 # 近似値
diameter = 3

# 直径の半分に等しい 'radius'（半径）という変数を作成する
____

# 円の面積の公式（円周率 × 半径の2乗）を使って 'area'（面積）という変数を作成する
____

# 解答を確認する
q1.check()

# %%
# ヒントを表示するにはコメントを外してください
#q1.hint()
# 解答を表示するにはコメントを外してください
#q1.solution()

# %% [markdown]
# <hr/>
#
# # 2.
#
# 変数 `a` と `b` の値を入れ替えるコードを以下のセルに追加してください（`a` が以前 `b` が参照していたオブジェクトを参照し、その逆になるようにします）。

# %%
########### セットアップコード - この部分は変更しないでください ######################
# 興味がある方へ：これらはリストの例です。
# 数レッスン後に詳しく学びます。今は、intやfloatと同じく
# Pythonオブジェクトの一種であることだけ知っておいてください。
a = [1, 2, 3]
b = [3, 2, 1]
q2.store_original_ids()
######################################################################

# ここにコードを書いてください。aとbが参照する値を入れ替えてください。
# 行き詰まったら、次のセルの行のコメントを外してヒントや解答を見ることができます。

######################################################################

# 解答を確認する
q2.check()

# %%
# ヒントを表示するにはコメントを外してください
#q2.hint()

# %%
# 解答を表示するにはコメントを外してください
#q2.solution()

# %% [markdown]
# <hr/>
#
# # 3a.
#
# 以下の式に括弧を追加して、結果が1になるようにしてください。

# %%
5 - 3 // 2

# %%
# ヒントを表示するにはコメントを外してください
#q3.a.hint()

# %%
# 解答を確認する（このコードセルを実行してクリアしてください！）
q3.a.solution()

# %% [markdown]
# # 3b.  <span title="少し難しい" style="color: darkgreen ">🌶️</span>
#
# <small>🌶️マークが付いた問題は少し難しめです。</small>
#
# 以下の式に括弧を追加して、結果が0になるようにしてください。

# %%
8 - 3 * 2 - 1 + 1

# %%
# ヒントを表示するにはコメントを外してください
#q3.b.hint()

# %%
# 解答を確認する（このコードセルを実行してクリアしてください！）
q3.b.solution()

# %% [markdown]
# <hr/>
#
# # 4.
# Alice、Bob、Carolはハロウィンのお菓子を集めて3人で均等に分けることにしました。
# 友情のために、余ったお菓子は砕いて捨てます。例えば、合計91個のお菓子を持ち帰った場合、
# 各自30個ずつ取り、1個を砕きます。
#
# 以下に、集めたお菓子の数に対して砕かなければならないお菓子の数を計算する算術式を書いてください。

# %%
# Alice、Bob、Carolが集めたお菓子の数を表す変数
alice_candies = 121
bob_candies = 77
carol_candies = 109

# ここにコードを書いてください！この代入の右辺を
# alice_candies、bob_candies、carol_candiesを使った式に置き換えてください
to_smash = -1

# 解答を確認する
q4.check()

# %%
# ヒントを表示するにはコメントを外してください
#q4.hint()
# 解答を表示するにはコメントを外してください
#q4.solution()

# %% [markdown]
# # 次に進む
#
# 次は、**[新しい関数の書き方と他の人が書いた関数の理解の仕方](https://www.kaggle.com/colinmorris/functions-and-getting-help)** を学びます。これにより、Pythonプログラマーとしての生産性が少なくとも10倍になるでしょう。

# %% [markdown]
# ---
#
# *質問やコメントがありますか？[コース ディスカッション フォーラム](https://www.kaggle.com/learn/python/discussion)を訪問して、他の学習者とチャットをしてみましょう。*
