# %% [markdown]
# # 第2回 理解度確認 — 関数
#
# このノートブックは、第2回で学んだ内容（関数の定義、引数、`return`、スコープ）を自分で確認するためのものです。
#
# 各問題のコードセルにあなたの答えを書いて実行してください。

# %% [markdown]
# ## 問題1: 一番シンプルな関数
#
# 引数を1つ受け取り、その値に `10` を足して返す関数 `add_ten` を定義してください。
#
# **期待される結果**:
# - `add_ten(5)` → `15`
# - `add_ten(100)` → `110`

# %%
# ここに関数を定義してください


# 動作確認
print(add_ten(5))
print(add_ten(100))

# %% [markdown]
# ## 問題2: 引数を使った計算
#
# あなたは時給制のアルバイトです。時給は `1100円` です。
#
# 働いた時間を引数に受け取り、給料を計算して返す関数 `get_pay` を定義してください。
#
# **期待される結果**:
# - `get_pay(8)` → `8800`
# - `get_pay(20)` → `22000`

# %%
# ここに関数を定義してください


# 動作確認
print(get_pay(8))
print(get_pay(20))

# %% [markdown]
# ## 問題3: 引数を複数受け取る関数
#
# あなたは配送会社で働いています。
#
# 荷物の縦・横・高さ（cm）を引数に受け取り、**体積（cm³）** を返す関数 `box_volume` を定義してください。
#
# **期待される結果**:
# - `box_volume(10, 20, 30)` → `6000`
# - `box_volume(5, 5, 5)` → `125`

# %%
# ここに関数を定義してください


# 動作確認
print(box_volume(10, 20, 30))
print(box_volume(5, 5, 5))

# %% [markdown]
# ## 問題4: 業務シナリオ
#
# あなたはカフェのレジシステムを開発しています。
#
# ドリンクの単価、注文数、トッピング代を引数に受け取り、**消費税10%込みの合計金額** を返す関数 `calc_total` を定義してください。
#
# 計算式:
# ```
# 小計 = 単価 × 数量 + トッピング代
# 合計 = 小計 × 1.1
# ```
#
# **期待される結果**:
# - `calc_total(500, 2, 100)` → `1210.0`
#   （500 × 2 + 100 = 1100、税込み 1210）
# - `calc_total(400, 3, 0)` → `1320.0`

# %%
# ここに関数を定義してください


# 動作確認
print(calc_total(500, 2, 100))
print(calc_total(400, 3, 0))

# %% [markdown]
# ## 問題5: 関数の中で別の関数を使う
#
# 問題2で作った `get_pay` を使ってください。
#
# 2人分の労働時間（`hours_a`, `hours_b`）を引数に受け取り、2人合わせた給料の合計を返す関数 `total_pay_for_two` を定義してください。
#
# **期待される結果**:
# - `total_pay_for_two(8, 10)` → `19800`
#   （8時間: 8800円、10時間: 11000円、合計: 19800円）

# %%
# ここに関数を定義してください


# 動作確認
print(total_pay_for_two(8, 10))

# %% [markdown]
# ## 問題6: スコープを理解する
#
# 次のコードを実行するとエラーが出ます。
#
# **実行する前に**、なぜエラーになるか予想してから実行してみてください。

# %%
def calc_area(width, height):
    area = width * height
    return area

calc_area(5, 10)
print(area)

# %% [markdown]
# **あなたの説明**:
#
# （なぜエラーになったか書いてください）

# %% [markdown]
# ## 問題7: return を忘れたバグ
#
# 次の関数は、呼び出しても期待した結果になりません。何が間違っているか見つけて、修正してください。

# %%
def double(x):
    result = x * 2

answer = double(7)
print(answer)

# %% [markdown]
# **修正版を下に書いてください。**

# %%
# 修正したコード
