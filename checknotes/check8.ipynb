# %% [markdown]
# # 第8回 理解度確認 — Booleansと条件分岐・リスト
#
# このノートブックは、第8回で学んだ内容（ブール値、`and`/`or`/`not`、`if`/`elif`/`else`、条件式、リスト、インデックス、スライス、リストのメソッド、タプル）を自分で確認するためのものです。

# %% [markdown]
# ## 問題1: ブール値の組み合わせ
#
# 次の式の結果を予想してから実行してください。
#
# - `True and False`
# - `True or False`
# - `not (3 > 5)`
# - `(10 > 5) and (2 < 1)`
# - `(1 == 1) or (2 == 3)`

# %%
# ここにコードを書いてください

# %% [markdown]
# ## 問題2: 条件分岐の関数
#
# 年齢を引数に受け取り、以下を返す関数 `ticket_price` を定義してください。
#
# - `6` 歳未満 → `0`（無料）
# - `6` 歳以上 `18` 歳未満 → `800`（子供料金）
# - `18` 歳以上 `65` 歳未満 → `1500`（大人料金）
# - `65` 歳以上 → `1000`（シニア料金）
#
# **期待される結果**:
# - `ticket_price(3)` → `0`
# - `ticket_price(10)` → `800`
# - `ticket_price(30)` → `1500`
# - `ticket_price(70)` → `1000`

# %%
# ここに関数を定義してください


print(ticket_price(3))
print(ticket_price(10))
print(ticket_price(30))
print(ticket_price(70))

# %% [markdown]
# ## 問題3: 条件式（三項演算子）
#
# 数値を引数に受け取り、偶数なら `"偶数"`、奇数なら `"奇数"` を返す関数 `even_or_odd` を、**条件式（`A if 条件 else B`）を使って1行で** 書いてください。
#
# **ヒント**: `n % 2 == 0` で偶数かどうか判定できます。
#
# **期待される結果**:
# - `even_or_odd(4)` → `"偶数"`
# - `even_or_odd(7)` → `"奇数"`

# %%
def even_or_odd(n):
    # 1行で書いてください
    return 

print(even_or_odd(4))
print(even_or_odd(7))

# %% [markdown]
# ## 問題4: リストの操作
#
# 次の `scores` に対して、以下の操作を順に行ってください。
#
# 1. 3番目の要素（インデックス2）を表示する
# 2. 最後の2要素をスライスで取り出して表示する
# 3. リスト全体を昇順にソートして表示する（`.sort()`）

# %%
scores = [72, 95, 60, 88, 45, 100, 67]

# ここにコードを書いてください

# %% [markdown]
# ## 問題5: リストのメソッド
#
# 次の `tasks` に対して、以下の操作を順に行ってください。
#
# 1. `"買い物"` を末尾に追加する（`.append()`）
# 2. `"掃除"` がリストの何番目にあるか調べて表示する（`.index()`）
# 3. 先頭の要素を取り出して削除する（`.pop(0)`）— 取り出した値も表示する
# 4. 操作後の `tasks` を表示する

# %%
tasks = ["洗濯", "掃除", "料理", "勉強"]

# ここにコードを書いてください

# %% [markdown]
# ## 問題6: タプル
#
# タプル `point = (3, 5)` から、1つ目の値を `x`、2つ目の値を `y` に取り出して（**アンパック**して）、`x + y` を表示してください。
#
# また、タプルの要素を変更しようとするとどうなるか、`point[0] = 10` を試して確認してください（エラーになるはずです）。

# %%
point = (3, 5)

# x, y にアンパックして表示


# point[0] = 10 を試す（コメントを外して実行）
# point[0] = 10

# %% [markdown]
# ## 問題7: バグを直す
#
# 次の関数は、リストの先頭と末尾の要素を入れ替えた新しいリストを返すつもりですが、正しく動きません。原因を見つけて修正してください。
#
# **期待される結果**: `swap_ends([1, 2, 3, 4, 5])` → `[5, 2, 3, 4, 1]`

# %%
def swap_ends(lst):
    lst[0] = lst[-1]
    lst[-1] = lst[0]
    return lst

print(swap_ends([1, 2, 3, 4, 5]))

# %% [markdown]
# **何が問題か説明し、修正版を下に書いてください。**

# %%
# 修正したコード
