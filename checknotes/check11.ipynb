# %% [markdown]
# # 第11回 理解度確認 — 外部ライブラリ
#
# このノートブックは、第11回で学んだ内容（`import`、サブモジュール、見慣れないオブジェクトの調べ方、演算子のオーバーロード）を自分で確認するためのものです。
#
# **やさしい問題から順に並んでいます。** 上から順番に取り組んでください。`____`（アンダースコア）の部分は、自分で正しいコードに書き換える場所です。

# %% [markdown]
# ## 問題1: ウォームアップ — math モジュールを使う
#
# `math` モジュールをインポートして、次の値を計算して表示してください。
#
# - `2` の平方根（`math.sqrt(2)`）
# - 円周率 `π`（`math.pi`）
#
# **ヒント**: まず `import math` と書いてから、`math.sqrt(...)` のように使います。

# %%
# ここにコードを書いてください

# %% [markdown]
# ## 問題2: math のいろいろな関数
#
# `math` モジュールには切り上げ・切り捨ての関数があります。
#
# `____` を埋めて、必要なサーバー台数の見積もりを計算してください。
#
# - `math.ceil(7.3)` … 切り上げ → `8`
# - `math.floor(7.8)` … 切り捨て → `7`

# %%
import math

rounded_up = math.____(7.3)
rounded_down = math.____(7.8)

print(rounded_up)
print(rounded_down)

# %% [markdown]
# ## 問題3: 別名（エイリアス）でインポート
#
# 長いモジュール名は、`as` を使って短い別名を付けられます。
#
# `____` を埋めて、`numpy` を `np` という別名でインポートしてください。

# %%
import numpy ____ np

arr = np.array([1, 2, 3, 4, 5])
print(arr)

# %% [markdown]
# ## 問題4: 別名でインポートして使う
#
# `numpy` を `np` という別名でインポートしてください。
#
# その後、レスポンスタイムの計測値 `np.array([14, 8, 27, 3, 19])` で配列を作り、その合計（`.sum()`）と平均（`.mean()`）を表示してください。

# %%
# ここにコードを書いてください

# %% [markdown]
# ## 問題5: from ... import
#
# モジュールの中から特定の関数だけをインポートすることもできます。
#
# `____` を埋めて、`random` モジュールから `randint` だけをインポートしてください。

# %%
from random ____ randint

# 1〜6のサイコロを1回振る
print(randint(1, 6))

# %% [markdown]
# ## 問題6: from ... import を使う
#
# `random` モジュールから `randint` だけをインポートしてください（`from random import randint`）。
#
# その後、`randint(1000, 9999)` を使って **4桁の一時パスワード（数字のみ）を5個** 生成し、リストに入れて表示してください。
#
# **ヒント**: リスト内包表記が使えます。`[randint(1000, 9999) for i in range(5)]`

# %%
# ここにコードを書いてください

# %% [markdown]
# ## 問題7: 見慣れないオブジェクトを調べる
#
# 次のコードで作られる `arr` がどんなオブジェクトか、`type()` を使って調べてください。
#
# また、`dir(arr)` を使って、`arr` が持っているメソッドの一覧を表示してください（たくさん出てきます）。
#
# その中から、配列の **最大値** を求めるメソッドを見つけて、実際に使ってみてください。

# %%
import numpy as np
arr = np.array([3, 14, 9, 27, 5])

# type() で調べる


# dir() で調べる


# 最大値を求めるメソッドを使う

# %% [markdown]
# ## 問題8: 演算子のオーバーロード
#
# 次のコードを実行して、結果を確認してください。
#
# ```python
# import numpy as np
# a = np.array([1, 2, 3])
# b = np.array([10, 20, 30])
# print(a + b)
# print(a * 2)
# ```
#
# 普通のリスト（`[1, 2, 3] + [10, 20, 30]` や `[1, 2, 3] * 2`）と結果がどう違うか、実際に両方を試して、下のセルに違いを書いてください。

# %%
import numpy as np
a = np.array([1, 2, 3])
b = np.array([10, 20, 30])
print("numpy配列:")
print(a + b)
print(a * 2)

print("普通のリスト:")
print([1, 2, 3] + [10, 20, 30])
print([1, 2, 3] * 2)

# %% [markdown]
# **numpy配列と普通のリストの違い**:
#
# （ここに書いてください）

# %% [markdown]
# ## 問題9: 動かないコードを直す
#
# 次のコードはエラーになります。エラーメッセージをよく読んで、何が間違っているか考えて修正してください。
#
# **ヒント**: `import math` でインポートした関数は、`math.` を付けて呼び出す必要があります。

# %%
import math
result = sqrt(16)
print(result)

# %% [markdown]
# **修正版を下に書いてください。**

# %%
# 修正したコード

# %% [markdown]
# ## 問題10: 考えてみよう — `import *` の問題
#
# 次の2つのインポートの書き方には、それぞれメリットとデメリットがあります。
#
# ```python
# # 書き方A
# import math
# print(math.sqrt(16))
#
# # 書き方B
# from math import *
# print(sqrt(16))
# ```
#
# 書き方B（`from math import *`）には、どんな問題が起こりうるでしょうか？下に考えを書いてください。
#
# **ヒント**: 複数のモジュールを `*` でインポートしたとき、同じ名前の関数が別のモジュールにもあったら、どちらが使われるか分かりにくくなります。

# %% [markdown]
# **あなたの考え**:
#
# （ここに書いてください）

# %% [markdown]
# ## 問11: ブラックジャックの手札の合計を求める
#
# 第8回で扱った **ブラックジャック** の「手札の合計点」を計算します。難しかった人も、小さなステップ（11-a 〜 11-e）に分けて一つずつ組み立てれば大丈夫です。
#
# **点数の数え方**:
#
# - 絵札（`'J'`, `'Q'`, `'K'`）は **10** として数える
# - 数字カードは、その数字のまま数える
# - `'A'`（エース）は **11 または 1** の好きな方で数える（合計が **21 を超えない範囲で、なるべく大きくなる** 方を選ぶ）
#
# 手札は **文字列のリスト** で表します。以降ではこの手札を通し例に使います。
#
# ```python
# hands = ['A', 'K', '7', '3']   # この手札の合計は 21
# ```
#
# 11-a から順に、`values`（絵札を10にしたリスト）→ 合計 → Aの枚数 → Aの分を加算、と組み立て、最後に 11-e で1つの関数にまとめます。

# %% [markdown]
# ### 問11-a: 絵札を10に入れ替える
#
# `for` 文を使って、`hands` の中の絵札（`'J'`, `'Q'`, `'K'`）を数値の `10` に置き換えた **新しいリスト `values`** を作ってください。絵札以外のカード（数字や `'A'`）はそのままにします。
#
# **期待する出力**（`hands = ['A', 'K', '7', '3']` のとき）:
#
# ```
# ['A', 10, '7', '3']
# ```
#
# **ヒント**: 空のリストを用意し、カードが絵札なら `10` を、それ以外ならそのカードを追加（`append`）していきます。

# %%
hands = ['A', 'K', '7', '3']

# 絵札(J,Q,K)を10に入れ替えた新しいリスト values を作ろう


print(values)

# %% [markdown]
# ### 問11-b: A以外の数字の合計を求める（`sum` を使う）
#
# 11-a で作った `values` から、**`'A'`（エース）を除いた** カードの数字を合計してください。合計には組み込み関数 **`sum()`** を使います。
#
# **期待する出力**（合計）:
#
# ```
# 20
# ```
#
# **ヒント**:
# - まず A 以外の数字だけを集めたリストを、リスト内包表記で作ります。文字列の数字は `int(...)` で数値に変換できます。型（文法）はこんな形です。自分で埋めてみましょう。
#   ```
#   numbers = [int(取り出した値) for 取り出した値 in values if 取り出した値がAでない]
#   ```
# - できたリストを `sum(リスト)` に渡すと合計が求められます。

# %%
values = ['A', 10, '7', '3']   # 11-a の結果

# A以外の数字を sum() で合計して total に入れよう


print(total)

# %% [markdown]
# ### 問11-c: Aの枚数を数える
#
# `values`（または `hands`）の中に **`'A'` が何枚あるか** を数えて、`aces` に入れてください。
#
# **期待する出力**:
#
# ```
# 1
# ```
#
# **ヒント**: `for` で1枚ずつ見て `'A'` のときにカウントを増やしてもよいですし、`values.count('A')` を使ってもかまいません。

# %%
values = ['A', 10, '7', '3']   # 11-a の結果

# A の枚数を数えて aces に入れよう


print(aces)

# %% [markdown]
# ### 問11-d: Aの枚数に応じて合計に足す
#
# A以外の合計 `total`（11-b ＝ 20）と、Aの枚数 `aces`（11-c ＝ 1）が分かっています。
# A の分を `total` に足して、**最終的な手札の合計** を求めてください。
#
# **数え方（分岐）**:
#
# - A は 11 か 1 のどちらかで数える
# - **1枚を 11、残りを 1** として数えても合計が **21 以下** なら、その数え方にする（なるべく大きく）
# - **21 を超えてしまう** なら、A は **すべて 1** として数える
#
# **期待する出力**（`total = 20`, `aces = 1` のとき）:
#
# ```
# 21
# ```
# （20 に 11 を足すと 31 で21を超えるので、A は 1 として数え、20 + 1 = 21）
#
# **ヒント**: `if` を使って「A を1枚だけ11、残りを1として足した値」で21を超えるかどうかで分岐します。

# %%
total = 20   # 11-b の結果（A以外の合計）
aces = 1     # 11-c の結果（Aの枚数）

# Aの枚数に応じて分岐し、Aの分を total に足して最終的な合計を求めよう


print(total)

# %% [markdown]
# ### 問11-e: 総合 — 手札の合計を求める関数を作る
#
# 11-a 〜 11-d で練習したことを組み合わせて、**手札のリストを受け取って合計点を返す** 関数 `hand_value` を完成させてください。
#
# **動作の例**:
#
# ```
# hand_value(['A', 'K', '7', '3'])  ->  21
# hand_value(['A', '6', '2'])       ->  19
# hand_value(['A', 'A', '9'])       ->  21
# hand_value(['K', 'Q', '5'])       ->  25   （21 を超えたら「バースト」）
# ```
#
# **組み立ての流れ**:
#
# 1. 絵札は 10、数字はその数として合計し、A は枚数を数える（11-a 〜 11-c）
# 2. A以外の合計に、A の分を分岐して足す（11-d）

# %%
def hand_value(hands):
    # ここに 11-a 〜 11-d を組み合わせて書こう
    pass


# 動作確認
print(hand_value(['A', 'K', '7', '3']))  # 21
print(hand_value(['A', '6', '2']))        # 19
print(hand_value(['A', 'A', '9']))        # 21
print(hand_value(['K', 'Q', '5']))        # 25
