# %% [markdown]
# # 第10回 理解度確認 — 文字列と辞書
#
# このノートブックは、第10回で学んだ内容（文字列のメソッド、`.split()` / `.join()`、`.format()`、辞書）を自分で確認するためのものです。

# %% [markdown]
# ## 問題1: 文字列のメソッド
#
# 文字列 `text = "  Hello, Python World!  "` に対して、次の操作の結果をそれぞれ表示してください。
#
# - 前後の空白を取り除く（`.strip()`）
# - すべて大文字にする（`.upper()`）
# - すべて小文字にする（`.lower()`）
# - `"Python"` を `"Java"` に置き換える（`.replace()`）

# %%
text = "  Hello, Python World!  "

# ここにコードを書いてください

# %% [markdown]
# ## 問題2: split() と join()
#
# **2-1.** 文字列 `"apple,banana,orange,grape"` を `,` で分割してリストにし、表示してください（`.split(",")`）。
#
# **2-2.** リスト `["2026", "05", "13"]` を `"-"` でつないで `"2026-05-13"` という文字列を作り、表示してください（`"-".join(...)`）。

# %%
# 2-1
fruits_str = "apple,banana,orange,grape"


# 2-2
date_parts = ["2026", "05", "13"]

# %% [markdown]
# ## 問題3: format() で文字列を作る
#
# 変数 `name = "田中"`、`score = 85` を使って、`.format()` を使い次の文字列を作って表示してください。
#
# ```
# 田中さんの点数は85点です
# ```

# %%
name = "田中"
score = 85

# ここにコードを書いてください

# %% [markdown]
# ## 問題4: 辞書の作成とアクセス
#
# あなたは社員管理システムを作っています。
#
# 次の情報を辞書 `employee` として作成してください。
#
# - `"name"` → `"山田太郎"`
# - `"age"` → `28`
# - `"department"` → `"開発部"`
#
# 作成したら、`employee["name"]` と `employee["department"]` を表示してください。

# %%
# ここにコードを書いてください

# %% [markdown]
# ## 問題5: 辞書の操作
#
# 問題4の `employee` に対して、以下の操作を順に行ってください。
#
# 1. `"email"` というキーで `"yamada@example.com"` を追加する
# 2. `"age"` の値を `29` に更新する
# 3. 辞書の全てのキーを表示する（`.keys()`）
# 4. `"phone"` というキーを `.get()` で取得する（存在しないので `None` が返るはず）
# 5. 操作後の `employee` を表示する

# %%
# ここにコードを書いてください

# %% [markdown]
# ## 問題6: 業務シナリオ
#
# あなたは在庫管理を任されました。
#
# 次の `inventory` 辞書には、商品名と在庫数が入っています。
#
# 以下の処理を行ってください。
#
# 1. `"ペン"` の在庫を `5` 増やす
# 2. `"消しゴム"` を新しく追加（在庫 `30`）
# 3. 全商品の在庫の合計を計算して表示する（`.values()` と `sum()`）

# %%
inventory = {"ノート": 50, "ペン": 120, "定規": 15}

# ここにコードを書いてください

# %% [markdown]
# ## 問題7: バグを直す
#
# 次のコードは、辞書から値を取り出そうとしてエラーになります。原因を見つけて、エラーにならないように修正してください（存在しないキーの場合は `"不明"` と表示）。

# %%
user = {"name": "佐藤", "age": 25}
print(user["address"])

# %% [markdown]
# **修正版を下に書いてください。** ヒント: `.get()` を使います。

# %%
# 修正したコード
