# %%
# 演習のセットアップ（変更しないでください）
# !pip install --upgrade --no-cache-dir git+https://github.com/yusukem99/pythoncorse1.git

# %% [markdown]
# **このノートブックは [Python](https://www.kaggle.com/learn/python) コースの演習です。チュートリアルは [こちらのリンク](https://www.kaggle.com/colinmorris/strings-and-dictionaries) から参照できます。**
#
# ---

# %%
コースもあと少しで完了です。よく頑張りましたね！

終わる前に、もう少し面白い問題があります。

いつも通り、問題に取り組む前に下のセットアップコードを実行してください。

# %% [markdown]
# # 演習のセットアップ（変更しないでください）
# from learntools.core import binder; binder.bind(globals())
# from learntools.python.ex6 import *
# print('セットアップ完了。')

# %%
まずは文字列のスピードラウンドでウォーミングアップしましょう。以下の文字列の長さはいくつでしょうか？

以下の5つの文字列それぞれについて、`len()` に渡した場合に返される値を予測してください。変数 `length` に答えを記録し、セルを実行して正しかったか確認してください。

# 0a.

# %%
a = ""
length = ____
q0.a.check()

# %% [markdown]
# # 0b.

# %%
b = "it's ok"
length = ____
q0.b.check()

# %% [markdown]
# # 0c.

# %%
c = 'it\'s ok'
length = ____
q0.c.check()

# %% [markdown]
# # 0d.

# %%
d = """hey"""
length = ____
q0.d.check()

# %% [markdown]
# # 0e.

# %%
e = '\n'
length = ____
q0.e.check()

# %%
# 1.

「データサイエンティストは80%の時間をデータのクリーニングに費やし、20%の時間をデータのクリーニングについて愚痴を言うことに費やす」という格言があります。アメリカの郵便番号データのクリーニングに役立つ関数を書いてみましょう。文字列が与えられた場合、その文字列が有効な郵便番号かどうかを返します。ここでの有効な郵便番号とは、ちょうど5桁の数字で構成される文字列のことです。

ヒント：`str` にはここで役立つメソッドがあります。`help(str)` を使って文字列メソッドの一覧を確認してください。

# %% [markdown]
# def is_valid_zip(zip_code):
#     """入力文字列が有効な（5桁の）郵便番号かどうかを返す。
#     """
#     pass
#
# # 解答を確認する
# q1.check()

# %%
# ヒントを表示するにはコメントを外してください
#q1.hint()
# 解答を表示するにはコメントを外してください
#q1.solution()

# %%
# 2.

ある研究者が何千もの新聞記事を収集しました。しかし、特定の単語を含む記事に焦点を当てたいと考えています。以下の関数を完成させて、記事のフィルタリングを手伝ってください。

関数は以下の基準を満たす必要があります：

- キーワード文字列がより大きな単語の一部としてのみ出現する文書は含めないでください。例えば、キーワード "closed" を検索している場合、"enclosed." という文字列は含めません。
- 大文字と小文字を区別しないでください。したがって、キーワードが "closed" の場合、"Closed the case." というフレーズは含まれます。
- ピリオドやカンマがマッチングに影響しないようにしてください。キーワードが "closed" の場合、"It is closed." は含まれます。ただし、他の種類の句読点はないと仮定して構いません。

# %% [markdown]
# def word_search(doc_list, keyword):
#     """
#     文書のリスト（各文書は文字列）とキーワードを受け取る。
#     キーワードを含むすべての文書の元のリストへのインデックス値のリストを返す。
#
#     例：
#     doc_list = ["The Learn Python Challenge Casino.", "They bought a car", "Casinoville"]
#     >>> word_search(doc_list, 'casino')
#     >>> [0]
#     """
#     pass
#
# # 解答を確認する
# q2.check()

# %%
# ヒントを表示するにはコメントを外してください
#q2.hint()
# 解答を表示するにはコメントを外してください
#q2.solution()

# %%
# 3.

次に、研究者は複数のキーワードで検索したいと考えています。以下の関数を完成させて手伝ってください。

（この関数を実装する際に、先ほど書いた `word_search` 関数を使うことをお勧めします。このようにコードを再利用すると、プログラムがより堅牢で読みやすくなり、タイピングの手間も省けます！）

# %% [markdown]
# def multi_word_search(doc_list, keywords):
#     """
#     文書のリスト（各文書は文字列）とキーワードのリストを受け取る。
#     各キーワードをキーとし、そのキーワードを含む文書の（doc_listからの）
#     インデックスのリストを値とする辞書を返す。
#
#     >>> doc_list = ["The Learn Python Challenge Casino.", "They bought a car and a casino", "Casinoville"]
#     >>> keywords = ['casino', 'they']
#     >>> multi_word_search(doc_list, keywords)
#     {'casino': [0, 1], 'they': [1]}
#     """
#     pass
#
# # 解答を確認する
# q3.check()

# %%
# 解答を表示するにはコメントを外してください
#q3.solution()

# %%
# 次に進む

たくさん学びましたね。しかし、優秀なプログラマーでも他のプログラマーが作った「ライブラリ」に大きく依存しています。**[最後のレッスン](https://www.kaggle.com/colinmorris/working-with-external-libraries)** でそれについて学びます。

# %% [markdown]
# ---
#
# *質問やコメントがありますか？[コース ディスカッション フォーラム](https://www.kaggle.com/learn/python/discussion)を訪問して、他の学習者とチャットをしてみましょう。*
