# %%
# Google Colab用セットアップ（ローカル環境では実行不要）
# !pip install --upgrade --no-cache-dir git+https://github.com/yusukem99/pythoncorse1.git

# %% [markdown]
# **このノートブックは [Python](https://www.kaggle.com/learn/python) コースの演習です。チュートリアルは [こちらのリンク](https://www.kaggle.com/colinmorris/loops-and-list-comprehensions) から参照できます。**
#
# ---

# %%
ここまで学んだことを使えば、もっと面白いプログラムが書けるようになります。以下の問題を解いてみてください。

いつも通り、問題に取り組む前に下のセットアップコードを実行してください。

# %% [markdown]
# # 演習のセットアップ（変更しないでください）
# from learntools.core import binder; binder.bind(globals())
# from learntools.python.ex5 import *
# print('セットアップ完了。')

# %%
# 1.

デバッグに運が必要だと感じたことはありませんか？以下のプログラムにはバグがあります。バグを特定して修正してみてください。

# %% [markdown]
# def has_lucky_number(nums):
#     """与えられた数値リストがラッキーかどうかを返す。ラッキーなリストには
#     7で割り切れる数が少なくとも1つ含まれている。
#     """
#     for num in nums:
#         if num % 7 == 0:
#             return True
#         else:
#             return False

# %%
バグを特定して、以下のセルで修正してみてください：

# %% [markdown]
# def has_lucky_number(nums):
#     """与えられた数値リストがラッキーかどうかを返す。ラッキーなリストには
#     7で割り切れる数が少なくとも1つ含まれている。
#     """
#     for num in nums:
#         if num % 7 == 0:
#             return True
#         else:
#             return False
#
# # 解答を確認する
# q1.check()

# %%
# ヒントを表示するにはコメントを外してください
#q1.hint()
# 解答を表示するにはコメントを外してください
#q1.solution()

# %%
# 2.
以下のPython式を見てください。実行するとどうなると思いますか？予測ができたら、コメントを外してセルを実行し、正しかったか確認してください。

# %%
RやPythonには（numpyやpandasのような）ライブラリがあり、リストの各要素を2と比較し（つまり「要素ごとの」比較を行い）、`[False, False, True, True]` のようなブール値のリストを返します。

この動作を再現する関数を実装してください。対応する要素がnより大きいかどうかに応じたブール値のリストを返します。

# %% [markdown]
# def elementwise_greater_than(L, thresh):
#     """Lと同じ長さのリストを返す。インデックスiの値は、
#     L[i]がthreshより大きい場合はTrue、そうでない場合はFalse。
#
#     >>> elementwise_greater_than([1, 2, 3, 4], 2)
#     [False, False, True, True]
#     """
#     pass
#
# # 解答を確認する
# q2.check()

# %%
# 解答を表示するにはコメントを外してください
#q2.solution()

# %%
# 3.

docstringに従って、以下の関数の本体を完成させてください。

# %% [markdown]
# def menu_is_boring(meals):
#     """ある期間に提供された食事のリストが与えられた場合、同じ食事が
#     2日連続で提供されたことがあればTrueを、そうでなければFalseを返す。
#     """
#     pass
#
# # 解答を確認する
# q3.check()

# %%
# ヒントを表示するにはコメントを外してください
#q3.hint()
# 解答を表示するにはコメントを外してください
#q3.solution()

# %%
# 4. <span title="少し難しい" style="color: darkgreen ">🌶️</span>

ブラックジャックテーブルの隣に、Python Challenge Casinoにはスロットマシンがあります。`play_slot_machine()` を呼ぶとスロットマシンの結果が得られます。返される数値はドルでの賞金額です。通常は0が返されますが、運が良ければ大当たりすることもあります。下で実行してみてください：

# %%
ちなみに、1回のプレイにつき1ドルかかることをお伝えしましたか？ご心配なく、後で請求書をお送りします。

平均して、1回プレイするごとにどれくらいの金額を獲得（または損失）できると思いますか？カジノはそれを秘密にしていますが、**モンテカルロ法**という手法を使って各プレイの平均値を推定できます。平均的な結果を推定するには、シナリオを何度もシミュレートし、平均結果を返します。

以下の関数を完成させて、スロットマシンの1回あたりの平均利益を計算してください。

# %% [markdown]
# def estimate_average_slot_payout(n_runs):
#     """スロットマシンをn_runs回実行し、1回あたりの平均純利益を返す。
#     呼び出し例（返り値は非決定的であることに注意）：
#     >>> estimate_average_slot_payout(1)
#     -1
#     >>> estimate_average_slot_payout(1)
#     0.5
#     """
#     pass

# %%
1回あたりの期待値がわかったと思ったら、下のコードセルを実行して解答を確認し、問題のクリア判定を受けてください。

# %% [markdown]
# # 解答を確認する（このコードセルを実行してクリアしてください！）
# q4.solution()

# %%
# 次に進む

多くのプログラマーが辞書をお気に入りのデータ構造だと言います。次のレッスンで**[辞書について学びます](https://www.kaggle.com/colinmorris/strings-and-dictionaries)**（文字列も一緒に）。

# %% [markdown]
# ---
#
# *質問やコメントがありますか？[コース ディスカッション フォーラム](https://www.kaggle.com/learn/python/discussion)を訪問して、他の学習者とチャットをしてみましょう。*
