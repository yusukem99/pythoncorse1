# %% [markdown]
# # 第10回 理解度確認 — 文字列と辞書
#
# このノートブックは、第10回で学んだ内容（文字列のメソッド、`.split()` / `.join()`、`.format()`、辞書）を自分で確認するためのものです。

# %% [markdown]
# ## 問題1: 文字列のメソッド
#
# ログから読み込んだ文字列 `line = "  GET /index.html HTTP/1.1  "` に対して、次の操作の結果をそれぞれ表示してください。
#
# - 前後の空白を取り除く（`.strip()`）
# - すべて大文字にする（`.upper()`）
# - すべて小文字にする（`.lower()`）
# - `"HTTP/1.1"` を `"HTTP/2"` に置き換える（`.replace()`）

# %%
line = "  GET /index.html HTTP/1.1  "

# ここにコードを書いてください

# %% [markdown]
# ## 問題2: split() と join()
#
# **2-1. IPアドレスの分解**
#
# 文字列 `"192.168.1.10"` を `.` で分割してリストにし、表示してください（`.split(".")`）。
#
# **2-2. 日付の組み立て**
#
# リスト `["2026", "05", "13"]` を `"-"` でつないで `"2026-05-13"` という文字列（ログのタイムスタンプ）を作り、表示してください（`"-".join(...)`）。

# %%
# 2-1
ip = "192.168.1.10"


# 2-2
date_parts = ["2026", "05", "13"]

# %% [markdown]
# ## 問題3: format() で文字列を作る
#
# 変数 `ip = "192.168.1.50"`、`port = 8080` を使って、`.format()` を使い次のログメッセージを作って表示してください。
#
# ```
# 接続元 192.168.1.50:8080 からアクセスがありました
# ```

# %%
ip = "192.168.1.50"
port = 8080

# ここにコードを書いてください

# %% [markdown]
# ## 問題4: 辞書の作成とアクセス
#
# サーバーの構成情報を管理しています。
#
# 次の情報を辞書 `server` として作成してください。
#
# - `"hostname"` → `"web-01"`
# - `"ip"` → `"192.168.1.10"`
# - `"port"` → `443`
#
# 作成したら、`server["hostname"]` と `server["ip"]` を表示してください。

# %%
# ここにコードを書いてください

# %% [markdown]
# ## 問題5: 辞書の操作
#
# 問題4の `server` に対して、以下の操作を順に行ってください。
#
# 1. `"protocol"` というキーで `"HTTPS"` を追加する
# 2. `"port"` の値を `8443` に更新する
# 3. 辞書の全てのキーを表示する（`.keys()`）
# 4. `"os"` というキーを `.get()` で取得する（存在しないので `None` が返るはず）
# 5. 操作後の `server` を表示する

# %%
# ここにコードを書いてください

# %% [markdown]
# ## 問題6: 業務シナリオ（アクセス元IPの集計）
#
# アクセスログから、IPアドレスごとのアクセス回数を数えます。
#
# 次の `access_log` には、アクセスしてきたIPアドレスが順番に並んでいます。
#
# `for` ループと辞書を使って、**各IPアドレスが何回アクセスしてきたか** を辞書 `ip_count` にまとめ、表示してください。
#
# **ヒント**: 辞書にキーがすでにあれば `+1`、なければ `1` で初期化します。`.get(キー, 0)` を使うと書きやすいです。
#
# **期待される結果（順不同）**: `{'192.168.1.10': 3, '192.168.1.20': 2, '192.168.1.30': 1}`

# %%
access_log = ["192.168.1.10", "192.168.1.20", "192.168.1.10",
              "192.168.1.30", "192.168.1.10", "192.168.1.20"]

ip_count = {}

# ここにコードを書いてください

# %% [markdown]
# ## 問題7: バグを直す
#
# 次のコードは、辞書から値を取り出そうとしてエラーになります。原因を見つけて、エラーにならないように修正してください（存在しないキーの場合は `"不明"` と表示）。

# %%
server = {"hostname": "web-01", "ip": "192.168.1.10"}
print(server["location"])

# %% [markdown]
# **修正版を下に書いてください。** ヒント: `.get()` を使います。

# %%
# 修正したコード
