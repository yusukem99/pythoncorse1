# %%
# Google Colab用セットアップ（ローカル環境では実行不要）
# !pip install --upgrade --no-cache-dir git+https://github.com/yusukem99/pythoncorse1.git

# %% [markdown]
# **このノートブックは [Python](https://www.kaggle.com/learn/python) コースの演習です。チュートリアルは [こちらのリンク](https://www.kaggle.com/colinmorris/lists) から参照できます。**
#
# ---

# %%
リストを使うと、より面白いことができるようになります。新しい知識を使って以下の問題を解いてください。まず以下のセルを実行してください。

# %% [markdown]
# # 演習のセットアップ（変更しないでください）
# from learntools.core import binder; binder.bind(globals())
# from learntools.python.ex4 import *
# print('セットアップ完了。')

# %%
# 1.

docstringに従って、以下の関数を完成させてください。

# %% [markdown]
# def select_second(L):
#     """与えられたリストの2番目の要素を返す。リストに2番目の要素がない場合は
#     Noneを返す。
#     """
#     pass
#
# # 解答を確認する
# q1.check()

# %%
# ヒントを表示するにはコメントを外してください
#q1.hint()
# 解答を表示するにはコメントを外してください
#q1.solution()

# %%
# 2.

あなたはスポーツチームを分析しています。各チームのメンバーはリストに格納されています。コーチはリストの最初の名前、キャプテンはリストの2番目の名前で、その後に他の選手が続きます。
これらのリストはさらに別のリストに格納されており、最強のチームから始まり、最弱のチームで終わります。以下の関数を完成させて、**最弱チームのキャプテン**を返すようにしてください。

# %% [markdown]
# def losing_team_captain(teams):
#     """チームのリスト（各チームは名前のリスト）が与えられた場合、
#     最後に記載されたチームの2番目の選手（キャプテン）を返す。
#     """
#     pass
#
# # 解答を確認する
# q2.check()

# %%
# ヒントを表示するにはコメントを外してください
#q2.hint()
# 解答を表示するにはコメントを外してください
#q2.solution()

# %%
# 3.

次のマリオカートには、超イライラする新アイテム「*パープルシェル*」が登場します。使用すると、最下位のレーサーを1位に、1位のレーサーを最下位にワープさせます。以下の関数を完成させて、パープルシェルの効果を実装してください。

# %% [markdown]
# def purple_shell(racers):
#     """レーサーのリストが与えられた場合、1位のレーサー（リストの先頭）を最下位に、
#     最下位のレーサーを1位に入れ替える。
#
#     >>> r = ["Mario", "Bowser", "Luigi"]
#     >>> purple_shell(r)
#     >>> r
#     ["Luigi", "Bowser", "Mario"]
#     """
#     pass
#
# # 解答を確認する
# q3.check()

# %%
# ヒントを表示するにはコメントを外してください
#q3.hint()
# 解答を表示するにはコメントを外してください
#q3.solution()

# %%
# 4.

以下のリストの長さはいくつでしょうか？変数 `lengths` にあなたの予測を入れてください。（各リストについて、`len()` を呼ばずに予測してみてください。）

# %% [markdown]
# a = [1, 2, 3]
# b = [1, [2, 3]]
# c = []
# d = [1, 2, 3][1:]
#
# # 以下のリストに予測を入れてください。lengthsには4つの数字が入ります。
# # 1つ目はaの長さ、2つ目はbの長さ、以下同様です。
# lengths = []
#
# # 解答を確認する
# q4.check()

# %%
# 下の行は解説を表示します
#q4.solution()

# %%
# 5. <span title="少し難しい" style="color: darkgreen ">🌶️</span>

パーティーに来た人とその到着順をリストで記録しています。例えば、以下のリストは7人のゲストがいるパーティーで、Adelaが最初に到着し、Fordが最後に到着したことを表しています：

    party_attendees = ['Adela', 'Fleda', 'Owen', 'May', 'Mona', 'Gilbert', 'Ford']

ゲストの少なくとも半分が到着した後に来た場合、そのゲストは「おしゃれに遅刻」したとみなされます。ただし、一番最後のゲストは除外されます（それはやりすぎです）。上の例では、MonaとGilbertだけが「おしゃれに遅刻」したゲストです。

以下の関数を完成させて、パーティー参加者のリストとある人物を受け取り、その人がおしゃれに遅刻したかどうかを返すようにしてください。

# %% [markdown]
# def fashionably_late(arrivals, name):
#     """パーティーへの到着順リストと名前が与えられた場合、
#     その名前のゲストがおしゃれに遅刻したかどうかを返す。
#     """
#     pass
#
# # 解答を確認する
# q5.check()

# %%
# ヒントを表示するにはコメントを外してください
#q5.hint()
# 解答を表示するにはコメントを外してください
#q5.solution()

# %%
# 次に進む

リストとタプルについてはこれで終わりです！次は**[ループについて学びます](https://www.kaggle.com/colinmorris/loops-and-list-comprehensions)**。ここからリストとタプルが本当に面白くなります。

# %% [markdown]
# ---
#
# *質問やコメントがありますか？[コース ディスカッション フォーラム](https://www.kaggle.com/learn/python/discussion)を訪問して、他の学習者とチャットをしてみましょう。*
