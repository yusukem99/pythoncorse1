# %%
# GitHub (yusukem99/pythoncorse1) から learntools パッケージをインストールする
# !pip install --upgrade --no-cache-dir git+https://github.com/yusukem99/pythoncorse1.git

print("✅ インストールが完了しました。")

# %% [markdown]
# **このノートブックは [プログラミング入門](https://www.kaggle.com/learn/intro-to-programming) コースの演習です。チュートリアルは [こちらのリンク](https://www.kaggle.com/alexisbcook/data-types) から参照できます。**
#
# ---

# %% [markdown]
# チュートリアルでは、浮動小数点数、整数、文字列、ブール値の4つの異なるデータ型について学びました。この演習では、それらを実際に試してみましょう。
#
# # ノートブックのセットアップ
#
# 次のコードセルを変更せずに実行して、ノートブックをセットアップしてください。

# %%
# 演習のセットアップ（変更しないでください）
from learntools.core import binder
binder.bind(globals())
from learntools.intro_to_programming.ex3 import *
print('セットアップ完了。')

# %% [markdown]
# # 問題 1
#
# チュートリアルで `int` 関数を使って浮動小数点数を整数に変換する方法を学びました。以下のコードセルを実行して、自分で試してみましょう。

# %%
# 浮動小数点数を定義する
y = 1.
print(y)
print(type(y))

# int関数で浮動小数点数を整数に変換する
z = int(y)
print(z)
print(type(z))

# %% [markdown]
# この場合、使用している浮動小数点数には小数点以下の数字がありません。
# - しかし、小数部分を持つ浮動小数点数を整数に変換しようとするとどうなるでしょうか？
# - 正の数と負の数で `int` 関数の結果はどのように変わるでしょうか？
#
# 次のコードセルを使って調べ、これらの質問に答えてください。自由にコードを追加したり削除したりしてください。ここはあなたの作業スペースです！

# %%
# コメントを外してコードを実行してみましょう！
#print(int(1.2321))
#print(int(1.747))
#print(int(-3.94535))
#print(int(-2.19774))

# %% [markdown]
# 答えがわかったら、以下のコードセルを実行して解答を確認してください。解答を表示すると、この問題の正解としてカウントされます。

# %%
# 解答を確認する（このコードセルを実行して正解を受け取ってください！）
q1.check()

# %% [markdown]
# # 問題 2
#
# チュートリアルでは、整数、浮動小数点数、文字列に加えて、ブール値（`True` または `False` の値を取る）について学びました。この問題では、ブール値にこれらのデータ型を掛けるとどうなるかを調べることが目標です。具体的には、
# - 整数または浮動小数点数に `True` を掛けるとどうなりますか？`False` を掛けるとどうなりますか？数値が正の場合と負の場合で答えはどう変わりますか？
# - 文字列に `True` を掛けるとどうなりますか？`False` を掛けるとどうなりますか？
#
# 次のコードセルを使って調べてみましょう。

# %%
# コメントを外してコードを実行してみましょう！
print(3 * True)
print(-3.1 * True)
print(type("abc" * False))
print(len("abc" * False))

# %% [markdown]
# 答えがわかったら、以下のコードセルを実行して解答を確認してください。解答を表示すると、この問題の正解としてカウントされます。

# %%
# 解答を確認する（このコードセルを実行して正解を受け取ってください！）
q2.check()

# %% [markdown]
# # 問題 3
#
# この問題では、前の演習で行った作業をもとに、家の価値を見積もる関数を作成します。
#
# 次のコードセルで、3つの変数を入力として受け取る関数 `get_expected_cost` を作成してください：
# - `beds` - ベッドルームの数（データ型：浮動小数点数）
# - `baths` - バスルームの数（データ型：浮動小数点数）
# - `has_basement` - 家に地下室があるかどうか（データ型：ブール値）
#
# この関数は、それらの特徴を持つ家の予想価格を返す必要があります。以下を前提とします：
# - ベッドルーム0個、バスルーム0個、地下室なしの家の予想価格は 80000 です。
# - ベッドルームが1つ増えるごとに、予想価格に 30000 が追加されます。
# - バスルームが1つ増えるごとに、予想価格に 10000 が追加されます。
# - 地下室があると、予想価格に 40000 が追加されます。
#
# 例えば、
# - ベッドルーム1個、バスルーム1個、地下室なしの家の予想価格は 80000 + 30000 + 10000 = 120000 です。この値は `get_expected_cost(1, 1, False)` で計算されます。
# - ベッドルーム2個、バスルーム1個、地下室ありの家の予想価格は 80000 + 2*30000 + 10000 + 40000 = 190000 です。この値は `get_expected_cost(2, 1, True)` で計算されます。
#
# ヒントが必要な場合は、次のコードセルの `q3.hint()` のコメントを外すことでいつでもヒントを見ることができます！

# %%
# TODO: 関数を完成させる
def get_expected_cost(beds, baths, has_basement):
    value = ____
    return value

# 解答を確認する
q3.check()

# %%
# ヒントを表示するにはコメントを外してください
#q3.hint()

# 解答を表示するにはコメントを外してください
#q3.solution()

# %% [markdown]
# # 問題 4
#
# ブール値の算術演算の学習を続けましょう。この問題では、ブール値同士を足し算するとどうなるかを説明することが課題です。
#
# 次のコードセルを使って調べてみましょう。自由にコードを追加したり削除したりしてください。ここはあなたの作業スペースです！

# %%
print(False + False)
print(True + False)
print(False + True)
print(True + True)
print(False + True + True + True)

# %% [markdown]
# 答えがわかったら、以下のコードセルを実行して解答を確認してください。解答を表示すると、この問題の正解としてカウントされます。

# %%
# 解答を確認する（このコードセルを実行して正解を受け取ってください！）
q4.check()

# %% [markdown]
# # 🌶️ 問題 5
#
# あなたはオンラインショップを経営しており、カスタム刻印入りのリングを販売しています。金メッキリングと純金リングの両方を提供しています。
# - 金メッキリングの基本価格は \$50 で、刻印1単位あたり \$7 の料金がかかります。
# - 純金リングの基本価格は \$100 で、刻印1単位あたり \$10 の料金がかかります。
# - スペースや句読点も刻印単位としてカウントされます。
#
# 2つの引数を受け取る関数 `cost_of_project()` を作成してください：
# - `engraving` - 刻印テキストのPython文字列
# - `solid_gold` - リングが純金かどうかを示すブール値
#
# この関数はプロジェクトのコストを返す必要があります。この問題はかなり難しいかもしれないので、ヒントが必要かもしれません。

# %%
def cost_of_project(engraving, solid_gold):
    cost = ____
    return cost

# 解答を確認する
q5.check()

# %%
# ヒントを表示するにはコメントを外してください
#q5.hint()

# 解答を表示するにはコメントを外してください
#q5.solution()

# %% [markdown]
# 次のコードセルを実行して、純金リングに `Charlie+Denver` と刻印するコストを計算してみましょう。

# %%
project_one = cost_of_project("Charlie+Denver", True)
print(project_one)

# %% [markdown]
# 次のコードセルを使って、金メッキリングに `08/10/2000` と刻印するコストを計算してみましょう。

# %%
project_two = cost_of_project("08/10/2000", False)
print(project_two)

# %% [markdown]
# # 次に進む
#
# 続いて **[条件と条件文（conditions and conditional statements）](https://www.kaggle.com/alexisbcook/conditions-and-conditional-statements)** について学びましょう。

# %% [markdown]
# ---
#
# *ご質問やご意見がありましたら、[コースのディスカッションフォーラム](https://www.kaggle.com/learn/intro-to-programming/discussion)で他の学習者と交流してください。*
