# %% [markdown]
# # 第11回 理解度確認 — 外部ライブラリ
#
# このノートブックは、第11回で学んだ内容（`import`、サブモジュール、見慣れないオブジェクトの調べ方、演算子のオーバーロード）を自分で確認するためのものです。

# %% [markdown]
# ## 問題1: math モジュールを使う
#
# `math` モジュールをインポートして、次の値を計算して表示してください。
#
# - `2` の平方根（`math.sqrt`）
# - 円周率 `π`（`math.pi`）
# - `7.3` を切り上げた値（`math.ceil`）
# - `7.8` を切り捨てた値（`math.floor`）

# %%
# ここにコードを書いてください

# %% [markdown]
# ## 問題2: 別名（エイリアス）でインポート
#
# `numpy` を `np` という別名でインポートしてください（`import numpy as np`）。
#
# その後、`np.array([1, 2, 3, 4, 5])` で配列を作り、その合計（`.sum()`）と平均（`.mean()`）を表示してください。

# %%
# ここにコードを書いてください

# %% [markdown]
# ## 問題3: from ... import
#
# `random` モジュールから `randint` だけをインポートしてください（`from random import randint`）。
#
# その後、`randint(1, 6)` を使ってサイコロを **5回振った結果** をリストに入れて表示してください。
#
# **ヒント**: リスト内包表記が使えます。

# %%
# ここにコードを書いてください

# %% [markdown]
# ## 問題4: 見慣れないオブジェクトを調べる
#
# 次のコードで作られる `arr` がどんなオブジェクトか、`type()` を使って調べてください。
#
# また、`dir(arr)` を使って、`arr` が持っているメソッドの一覧を表示してください（たくさん出てきます）。
#
# その中から、配列の **最大値** を求めるメソッドを見つけて、実際に使ってみてください。

# %%
import numpy as np
arr = np.array([3, 14, 9, 27, 5])

# type() で調べる


# dir() で調べる


# 最大値を求めるメソッドを使う

# %% [markdown]
# ## 問題5: 演算子のオーバーロード
#
# 次のコードを実行して、結果を確認してください。
#
# ```python
# import numpy as np
# a = np.array([1, 2, 3])
# b = np.array([10, 20, 30])
# print(a + b)
# print(a * 2)
# ```
#
# 普通のリスト（`[1, 2, 3] + [10, 20, 30]` や `[1, 2, 3] * 2`）と結果がどう違うか、実際に両方を試して、下のセルに違いを書いてください。

# %%
import numpy as np
a = np.array([1, 2, 3])
b = np.array([10, 20, 30])
print("numpy配列:")
print(a + b)
print(a * 2)

print("普通のリスト:")
print([1, 2, 3] + [10, 20, 30])
print([1, 2, 3] * 2)

# %% [markdown]
# **numpy配列と普通のリストの違い**:
#
# （ここに書いてください）

# %% [markdown]
# ## 問題6: バグを直す
#
# 次のコードはエラーになります。エラーメッセージを読んで、何が間違っているか考えて修正してください。

# %%
import math
result = sqrt(16)
print(result)

# %% [markdown]
# **修正版を下に書いてください。**

# %%
# 修正したコード

# %% [markdown]
# ## 問題7: 考えてみよう
#
# 次の2つのインポートの書き方には、それぞれメリットとデメリットがあります。
#
# ```python
# # 書き方A
# import math
# print(math.sqrt(16))
#
# # 書き方B
# from math import *
# print(sqrt(16))
# ```
#
# 書き方B（`from math import *`）には、どんな問題が起こりうるでしょうか？下に考えを書いてください。
#
# **ヒント**: 複数のモジュールを `*` でインポートしたときに何が起こるか考えてみましょう。

# %% [markdown]
# **あなたの考え**:
#
# （ここに書いてください）
