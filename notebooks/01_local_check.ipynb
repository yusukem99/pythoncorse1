# %% [markdown]
# # ローカル動作確認用ノートブック
# GitHubにプッシュする前に、手元のファイル（日本語化パッチ適用済み）が正しく動作するか確認します。

# %%
import sys
import os

# 今開いているノートブックの場所から、レポジトリのルートパスを特定して追加
# (notebooks/ フォルダにいる想定で、1つ上の階層を追加します)
repo_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if repo_root not in sys.path:
    sys.path.append(repo_root)

from learntools.core import binder
binder.bind(globals())
from learntools.python.ex1 import *

print("✅ 準備完了。現在のパス:", repo_root)

# %% [markdown]
# ## 判定テスト（日本語になっているか？）

# %%
# 正解の場合
color = 'blue'
print("--- 正解のテスト ---")
q0.check()

# %%
# 不正解の場合
color = 'red'
print("\n--- 不正解のテスト ---")
q0.check()
