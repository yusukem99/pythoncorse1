# %%
# 演習のセットアップ（変更しないでください）
# !pip install --upgrade --no-cache-dir git+https://github.com/yusukem99/pythoncorse1.git

# %% [markdown]
# **このノートブックは [Python](https://www.kaggle.com/learn/python) コースの演習です。チュートリアルは [こちらのリンク](https://www.kaggle.com/colinmorris/functions-and-getting-help) から参照できます。**
#
# ---

# %% [markdown]
# 関数は強力です。自分で書いてみましょう。
#
# 前回と同様に、問題1に進む前に下のセットアップコードを実行するのを忘れないでください。

# %%
# 演習のセットアップ（変更しないでください）
from learntools.core import binder; binder.bind(globals())
from learntools.python.ex2 import *
print('セットアップ完了。')

# %% [markdown]
# # 1.
#
# docstringに従って、以下の関数の本体を完成させてください。
#
# ヒント：Pythonには組み込み関数 `round` があります。

# %%
def round_to_two_places(num):
    """与えられた数値を小数点以下2桁に丸めて返す。
    
    >>> round_to_two_places(3.14159)
    3.14
    """
    # この本体を自分のコードに置き換えてください。
    # （"pass"は文字通り何もしないキーワードです。コードブロックの開始後、
    # Pythonは少なくとも1行のコードを必要とするため、プレースホルダーとして使用しています）
    pass

# 解答を確認する
q1.check()

# %%
# ヒントを表示するにはコメントを外してください
#q1.hint()
# 解答を表示するにはコメントを外してください
#q1.solution()

# %% [markdown]
# # 2.
# `round` のヘルプによると、`ndigits`（第2引数）は負の値にできるそうです。
# 負の値にするとどうなると思いますか？以下のセルでいくつか試してみてください。

# %%
# ここにテストコードを書いてください

# %% [markdown]
# これが役立つケースを思いつきますか？準備ができたら、下のコードセルを実行して解答を確認し、問題のクリア判定を受けてください。

# %%
# 解答を確認する（このコードセルを実行してクリアしてください！）
q2.solution()

# %% [markdown]
# # 3.
#
# 前回の演習で、お菓子を分け合う友人Alice、Bob、Carolは、お菓子を均等に分けようとしました。友情のために、余ったお菓子は砕いて捨てます。例えば、合計91個のお菓子を持ち帰った場合、各自30個ずつ取り、1個を砕きます。
#
# 以下は、お菓子の合計数に対して砕くべきお菓子の数を計算するシンプルな関数です。
#
# この関数を修正して、お菓子を分ける友人の数を表す第2引数をオプションで受け取れるようにしてください。第2引数が指定されない場合は、以前と同様に3人の友人を想定してください。
#
# この新しい動作を反映するようにdocstringも更新してください。

# %%
def to_smash(total_candies):
    """与えられたお菓子の数を3人の友人で均等に分けた後に、
    砕かなければならない余りのお菓子の数を返す。
    
    >>> to_smash(91)
    1
    """
    return total_candies % 3

# 解答を確認する
q3.check()

# %%
# ヒントを表示するにはコメントを外してください
#q3.hint()

# %%
# 解答を表示するにはコメントを外してください
#q3.solution()

# %% [markdown]
# # 4.（オプション）
#
# 楽しくはないかもしれませんが、エラーメッセージを読んで理解することは、Pythonプログラマーとして重要なスキルです。
#
# 以下の各コードセルには、コメントアウトされたバグのあるコードが含まれています。各セルについて...
#
# 1. コードを読んで、実行するとどうなるか予測してください。
# 2. コメントを外してコードを実行し、予測が正しかったか確認してください。（**ヒント**：エディタで複数行を選択して `Ctrl`+`/` を押すと、コメントの切り替えができます。）
# 3. コードを修正してください（例外をスローせずに意図した目的を達成するように）

# %%
# ruound_to_two_places(9.9999)

# %%
# x = -10
# y = 5
# # 上の2つの変数のうち、絶対値が小さいのはどちらか？
# smallest_abs = min(abs(x, y))

# %%
# def f(x):
#     y = abs(x)
# return y

# print(f(5))

# %% [markdown]
# # 次に進む
#
# コードをうまく書けましたね。次は*条件分岐*について学びます。これは**[面白いプログラムを書く](https://www.kaggle.com/colinmorris/booleans-and-conditionals)** ために必要です。

# %% [markdown]
# ---
#
# *質問やコメントがありますか？[コース ディスカッション フォーラム](https://www.kaggle.com/learn/python/discussion)を訪問して、他の学習者とチャットをしてみましょう。*
