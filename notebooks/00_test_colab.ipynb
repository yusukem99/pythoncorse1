# %% [markdown]
# # Kaggle Learn 授業用 テストノートブック (Colab版)
# このノートブックは、レポジトリ内の `learntools` が正しくColab環境で動作するかを確認するためのテスト用です。

# %% [markdown]
# ## 1. 準備 (環境構築)
# 以下のセルを実行して、先生のGitHubレポジトリから教材システムをインストールします。
#
# （初回実行時のみ、このセルを実行してください）

# %%
# GitHub (yusukem99/pythoncorse1) から learntools パッケージをインストールする
# !pip install --upgrade --no-cache-dir git+https://github.com/yusukem99/pythoncorse1.git

import sys
import pandas as pd
import learntools

print("✅ インストールと読み込みが完了しました。")
# Out:
# ...
#   Cloning https://github.com/yusukem99/pythoncorse1.git to c:\users\yusuke\appdata\local\temp\pip-req-build-4mpa2r89
#   Resolved https://github.com/yusukem99/pythoncorse1.git to commit 3cb79559279479d9df2a21cf2bacce974915639c
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
# Using legacy 'setup.py install' for learntools, since package 'wheel' is not installed.
# ...
#   Attempting uninstall: learntools
#     Found existing installation: learntools 0.2
#     Uninstalling learntools-0.2:
#       Successfully uninstalled learntools-0.2
#   Running setup.py install for learntools: started
#   Running setup.py install for learntools: finished with status 'done'
# ...
# ✅ インストールと読み込みが完了しました。
#   Running command git clone --filter=blob:none --quiet https://github.com/yusukem99/pythoncorse1.git 'C:\Users\yusuke\AppData\Local\Temp\pip-req-build-4mpa2r89'
#
# [notice] A new release of pip available: 22.2.1 -> 26.0.1
# ...

# %% [markdown]
# ## 2. 採点システムの起動
# インストールした `learntools` から、Pythonコースの第1章(ex1)の採点ツールを呼び出します。

# %%
from learntools.core import binder
binder.bind(globals())
from learntools.python.ex1 import *

print("✅ 採点システムの起動に成功しました！")
# Out:
# WARNING:root:Ignoring repeated attempt to bind to globals
# ✅ 採点システムの起動に成功しました！

# %% [markdown]
# ## 3. 問題への解答と採点テスト
# 以下の問題に解答し、`q0.check()` などの自動採点が機能するか確認します。
#
# **問題:** 変数 `color` に文字列 `'blue'` を代入してください。

# %%
# 答えを入力
color = 'blue'

# 採点を実行
q0.check()
# Out:
# 正解！: What?! You got it right without needing a hint or anything? Drats. Well hey, you should still continue to the next step to get some practice asking for a hint and checking solutions. (Even though you obviously don't need any help here.)

# %% [markdown]
# ヒントや正解を見るには以下のコメントを外して実行します。

# %%
# q0.hint()
# q0.solution()
