# %% [markdown]
# # Kaggle Learn 授業用 テストノートブック
# このノートブックは、レポジトリ内の `learntools` が正しくColab環境で動作するかを確認するためのテスト用です。

# %% [markdown]
# ## 1. 準備 (環境構築)
# 以下のセルを実行して、先生のGitHubレポジトリから教材システムをダウンロードし、パスを通します。
#
# （初回実行時のみ、このセルを実行してください）

# %%
# GitHub (yusukem99/pythoncorse1) から教材を含むレポジトリをクローンする
# !git clone https://github.com/yusukem99/pythoncorse1.git /content/pythoncorse1

import sys

# クローンしたレポジトリのルートパスをシステムのパスに追加
repo_root = '/content/pythoncorse1'
sys.path.append(repo_root)

print("✅ 準備が完了しました。レポジトリルートへのパス:", repo_root)

# %% [markdown]
# ## 2. 採点システムの起動
# ローカルに取り込んだ `learntools` から、Pythonコースの第1章(ex1)の採点ツールを呼び出します。

# %%
from learntools.core import binder
binder.bind(globals())
from learntools.python.ex1 import *

print("✅ 採点システムの読み込みに成功しました！")

# %% [markdown]
# ## 3. 問題への解答と採点テスト
# 以下の問題に解答し、`q0.check()` などの自動採点が機能するか確認します。
#
# **問題:** 変数 `color` に文字列 `'blue'` を代入してください。

# %%
# 答えを入力
color = 'blue'

# 採点を実行
q0.check()

# %% [markdown]
# ヒントや正解を見るには以下のコメントを外して実行します。

# %%
# q0.hint()
# q0.solution()
