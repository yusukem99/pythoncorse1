# %% [markdown]
# **このノートブックは [Python](https://www.kaggle.com/learn/python) コースの演習です。チュートリアルは [こちらのリンク](https://www.kaggle.com/colinmorris/loops-and-list-comprehensions) から参照できます。**
#
# ---

# %% [markdown]
# ここまで学んだループとリスト内包表記を使って、いくつかの問題に挑戦してみましょう。
#
# 問題に取り組む前に、下のセットアップコードを実行してください。

# %%
# 演習のセットアップ（変更しないでください）
# !pip install --force-reinstall --no-deps --no-cache-dir https://github.com/yusukem99/pythoncorse1/releases/download/learntools-v0.3/learntools-0.3-py3-none-any.whl
from learntools.core import binder; binder.bind(globals())
from learntools.python.ex5 import *
print('セットアップ完了。')

# %% [markdown]
# # 1.
#
# 次のプログラムにはバグがあります。どこが間違っているか見つけて、修正してみましょう。

# %%
def has_lucky_number(nums):
    """与えられた数値リストがラッキーかどうかを返す。ラッキーなリストには
    7で割り切れる数が少なくとも1つ含まれている。
    """
    for num in nums:
        if num % 7 == 0:
            return True
        else:
            return False

# %% [markdown]
# 次のセルで修正版を書いてみましょう：

# %%
def has_lucky_number(nums):
    """与えられた数値リストがラッキーかどうかを返す。ラッキーなリストには
    7で割り切れる数が少なくとも1つ含まれている。
    """
    for num in nums:
        if num % 7 == 0:
            return True
        else:
            return False

# 解答を確認する
q1.check()

# %%
# ヒントを表示するにはコメントを外してください
#q1.hint()
# 解答を表示するにはコメントを外してください
#q1.solution()

# %% [markdown]
# # 2.
#
# 次のPython式は実行するとどうなるでしょうか？まず予想してから、コメントを外して実行し、答えあわせをしてみましょう。

# %%
#[1, 2, 3, 4] > 2

# %% [markdown]
# 実は、numpyやpandasといったライブラリでは、リストと数値を比較するとリストの各要素ごとに比較が行われ、`[False, False, True, True]` のようなブール値のリストが返ってきます。
#
# この「要素ごとの比較」を自前で実装する関数を作ってみましょう。リスト `L` と数値 `thresh` を受け取り、各要素が `thresh` より大きいかどうかをブール値のリストとして返します。

# %%
def elementwise_greater_than(L, thresh):
    """リスト L と同じ長さのリストを返す。i番目の要素は、L[i] が thresh より大きければ True、そうでなければ False。
    
    >>> elementwise_greater_than([1, 2, 3, 4], 2)
    [False, False, True, True]
    """
    pass

# 解答を確認する
q2.check()

# %%
# 解答を表示するにはコメントを外してください
#q2.solution()

# %% [markdown]
# # 3.
#
# docstringの説明に従って、次の関数の中身を実装してください。

# %%
def menu_is_boring(meals):
    """ある期間に提供された食事のリストが与えられた場合、同じ食事が
    2日連続で提供されたことがあればTrueを、そうでなければFalseを返す。
    """
    pass

# 解答を確認する
q3.check()

# %%
# ヒントを表示するにはコメントを外してください
#q3.hint()
# 解答を表示するにはコメントを外してください
#q3.solution()

# %% [markdown]
# # 4. <span title="少し難しい" style="color: darkgreen ">🌶️</span>
#
# ここではスロットマシンを題材にします。`play_slot_machine()` を呼ぶと、スロットの結果（賞金額・単位はドル）が返ってきます。たいていは `0` ですが、たまに大当たりが出ます。下のセルで何度か実行してみてください。

# %%
play_slot_machine()

# %% [markdown]
# 実は、このスロットマシンは1回プレイするごとに1ドル必要です。
#
# 1回あたり、平均してどれくらい得（または損）するでしょうか？正確な値は分かりませんが、**モンテカルロ法** という考え方を使うと推定できます。試行を何度も繰り返して、その平均をとる、というシンプルな手法です。
#
# 次の関数を完成させて、スロットマシン1回あたりの平均利益を計算してみましょう。

# %%
def estimate_average_slot_payout(n_runs):
    """スロットマシンを n_runs 回プレイして、1回あたりの平均純利益を返す。
    （返り値はランダムなので、毎回違う値になることに注意）
    呼び出し例：
    >>> estimate_average_slot_payout(1)
    -1
    >>> estimate_average_slot_payout(1)
    0.5
    """
    pass

# %% [markdown]
# 1回あたりの平均利益が求められたら、下のセルを実行して解答を確認してください。

# %%
# 解答を確認する（このコードセルを実行してクリアしてください！）
q4.solution()

# %% [markdown]
# # 次に進む
#
# 次のレッスンでは、**[文字列と辞書](https://www.kaggle.com/colinmorris/strings-and-dictionaries)** を学びます。辞書はとても便利なデータ構造で、Pythonプログラマーの多くがお気に入りに挙げます。

# %% [markdown]
# ---
#
# *質問やコメントがありますか？[コース ディスカッション フォーラム](https://www.kaggle.com/learn/python/discussion)を訪問して、他の学習者とチャットをしてみましょう。*
